# %%
def composition(k, text):
    composition_list = []
    for i in range(len(text)-k+1):
        composition_list.append(text[i:i+k])
    #composition_list.sort()
    return composition_list

# %%
a = composition(100, dna_data[1])

# %%
with open('/home/jeongyeojin/dataset_200_8.txt') as f:
    data = f.read()
    dna_data = data.split('\n')[:-1]
print(dna_data)
# Out:
# ['CAAATTTAGACAGACAGCAA', 'CCTCGGCACGCATTGCCCTA', 'GATATGGCAATGCATGCGAA', 'TAGGCGCAACATGCTCACGC', 'AGGCGGCTAGTCGACTCCCG', 'AAACTAATACCTATAGTAAA', 'CGCCAGCCGATCAGGTAGTT', 'GCCCTATCTACTTCTGAACT', 'GCTAGCGAATAGGACTCGTG', 'GGTAGCGTATCGTCATTATG', 'GTACCAGCTTGAATCCTGAT', 'TTTACGACGACGGTACACTT', 'CGATCAGGTAGTTGGCAGGC', 'CATGATCCGCCACAGTGAGG', 'TGGCAATGCATGCGAACACC', 'AAGAGTGGCCATACTTTTAC', 'CTGAGCAACATTTACGACGA', 'TGTGTGCTACGTCGCTTGAT', 'TAGCGTATCGTCATTATGAT', 'TTCCAAAAGGAGGCCCAATT', 'CTGTTGCGTGGGCGATTGCC', 'GGTAACGTACCAGCTTGAAT', 'TGGCGGAGAATCTAGAAGTA', 'AATTTGAGTGCCCGTATGGC', 'GCGGCTACCCCATACTCCAG', 'GGTCCAGCGAAGCAAACCCG', 'GATGTTTTGACCCTCTCACC', 'AGACAGCGTGCTTAAGTTCC', 'ACAGATGCGTGTCTGTAAGG', 'CCCTACTACGGAGCATACCG', 'AGTGGCCATACTTTTACCAA', 'TTTGGCGGAGTACCCTTGTG', 'GAGCATACCGAGGGGGGCCG', 'GCCGAGATTTTTTACTCGTG', 'TGGAGACAGCGTGCTTAAGT', 'TTGGTCTCTACGTCTGCAGA', 'GCCATGAAATGCACATAACC', 'GAGTGTTCGAGAGATATTGA', 'TGGGCGCGCGGGCAGCAAAT', 'GACGAAATGCTGGGTAGCGT', 'TGGCCGCCCTACTACGGAGC', 'TGGAGTACGTATGGTCCAGC', 'TAGCGAATAGGACTCGTGGA', 'TGGGTCGTCCGGTTAATATA', 'TCGACTCCCGCGTATGATTT', 'GTTGGGTAAACTTAGTGGCG', 'GGCGCTTACCGAAGCGAAGG', 'CGTGGGCGATTGCCATTTAT', 'GTTGGCAGGCGCCACGGTCG', 'GGCGGAGTACCCTTGTGGCG', 'CGAATTGGGCCTTTGAGGAC', 'TACCGAAGCGAAGGTCTCCA', 'TATCGTCATTATGATTAGGT', 'TTCAGTACATGATCCGCCAC', 'CGCCTCAATCATCGCTGAAA', 'CTGATACTTCAAGGGTGAGG', 'GAGGTGGGTCAATAATTGCT', 'GGCCGTTCGCTTCTACCAAC', 'GCTAGGCGCAACATGCTCAC', 'CACAGTGAGGACGAGTATAG', 'ACAAGTCCTATTATAAAGGT', 'GAAGTAAAACTAATACCTAT', 'GCCATGATCTGGCAGAAGCG', 'GGTACACTTTTGGCCTAAAT', 'CTGGACTCAGCGTTCGCTTC', 'AGTTTTCCGCTCGAACGCAA', 'ACGAGTATAGCATGCAGGAA', 'ATGTTAAAGAGATTACCTAC', 'CCGGAAGA
TG', 'ATATTCTTTCGGCAAGGAGT', 'TCTAGAAGTAAAACTAATAC', 'AGAGATTACCTACTGATACT', 'ACTTCAAGGGTGAGGTGGGT', 'CTGAGCTGATCGCCAGCCGA', 'CGCAACATGCTCACGCTCAT', 'GCGTTCGCTTCAAATATTAC', 'TAATTGCTGCCGAGATTTTT', 'TCCTCGGCACGCATTGCCCT', 'ATCTGTGTGCTACGTCGCTT', 'GGACGAGTATAGCATGCAGG', 'GCATTCTCGCCGCTGTGGAT', 'AGAGGCGGCTACCCCATACT', 'ATTTCGGGTCGTACAAAGTC', 'CGAGAGGCGGCTACCCCATA', 'GTGGAATTAACGCTGCTCCA', 'ACGTCTGCAGAACCTTATTC', 'CCGAATTGGGCCTTTGAGGA', 'TTACTTGTTAAAAAGCTGGA', 'CAAGGAGTTTTCGCAGTTTC', 'CGTACATCCACAGAGGTAAC', 'CAAGGCGGTTTCGGACTCCT', 'AGATGCGTGTCTGT ...

# %%
def genome_path(patterns):
    genome_path = ''
    genome_path += patterns[0]
    for i in range(len(patterns)-1):
        genome_path += patterns[i+1][-1]
    return genome_path

# %%
sample_patterns = ['ACCGA', 'CCGAA','CGAAG','GAAGC','AAGCT']

# %%
edge_set = [(1,6),(1,7),(1,9),(2,3),(2,8),(2,10),(3,9),(3,11),(4,10),(4,12),(5,7),(5,11),(6,8),(6,12),(7,12),(10,11)]

# %%
from collections import defaultdict

def overlap_graph(patterns):
    overlapGraph = defaultdict(list)
    for i in range(len(patterns)):
        for j in range(len(patterns)):
            if i != j and patterns[i][1:] == patterns[j][:-1]:
                overlapGraph[i].append(j)
    return overlapGraph

# %%
og_dict = overlap_graph(dna_data)

# %%
for x, y in og_dict.items():
    for y_ in y:
        print("{} -> {}".format(dna_data[x], dna_data[y_]))

# %%
def deBrujin(text, k):
    patterns = [text[i:i+k-1] for i in range(len(text)-k+2)]
    debrujin_dict = defaultdict(list)
    for i in range(len(patterns)-1):
        debrujin_dict[patterns[i]].append(patterns[i+1])
    for x, y in debrujin_dict.items():
        print("{} -> {}".format(x, ", ".join(y)))

# %%
deBrujin('TAATGCCATGGGATGTT', 2)
# Out:
# T -> A, G, G, G, T
# A -> A, T, T, T
# G -> C, G, G, A, T
# C -> C, A

# %%
deBrujin('TAATGCCATGGGATGTT', 3)
# Out:
# TA -> AA
# AA -> AT
# AT -> TG, TG, TG
# TG -> GC, GG, GT
# GC -> CC
# CC -> CA
# CA -> AT
# GG -> GG, GA
# GA -> AT
# GT -> TT

# %%
deBrujin('TAATGGGATGCCATGTT', 3)
# Out:
# TA -> AA
# AA -> AT
# AT -> TG, TG, TG
# TG -> GG, GC, GT
# GG -> GG, GA
# GA -> AT
# GC -> CC
# CC -> CA
# CA -> AT
# GT -> TT

# %%
def deBrujin_from_kmers(kmers):
    debrujin_dict = defaultdict(list)
    for x in kmers:
        debrujin_dict[x[:-1]].append(x[1:])
    for x, y in debrujin_dict.items():
        print("{} -> {}".format(x, ", ".join(y)))

# %%
deBrujin_from_kmers(['000','001','010','011','100','101','110','111'])
# Out:
# 00 -> 00, 01
# 01 -> 10, 11
# 10 -> 00, 01
# 11 -> 10, 11
